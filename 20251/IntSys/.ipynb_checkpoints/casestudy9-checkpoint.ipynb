# %%
# Cell 1: Import thư viện
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
# Cell 2: Load và tiền xử lý dữ liệu
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Chuẩn hóa dữ liệu
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Chia validation set từ training set
x_val = x_train[-10000:]
y_val = y_train[-10000:]
x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %%
# Cell 3: Xây dựng mô hình MLP đơn giản
model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# C:\Python313\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Cell 4: Huấn luyện mô hình với số epoch lớn để dễ thấy overfitting
history = model.fit(
    x_train, y_train,
    epochs=20,
    batch_size=128,
    validation_data=(x_val, y_val)
)
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8957 - loss: 0.3717 - val_accuracy: 0.9513 - val_loss: 0.1768
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9558 - loss: 0.1508 - val_accuracy: 0.9627 - val_loss: 0.1248
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9691 - loss: 0.1047 - val_accuracy: 0.9710 - val_loss: 0.1016
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9769 - loss: 0.0778 - val_accuracy: 0.9715 - val_loss: 0.0976
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9815 - loss: 0.0619 - val_accuracy: 0.9741 - val_loss: 0.0896
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9848 - loss: 0.0503 - val_accuracy: 0.9754 - val_loss: 0.0817
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9882 - loss: 0.0399 - val_accuracy: 0.9775 - val_loss: 0.0783
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9902 - loss: 0.0334 - val_accuracy: 0.9756 - val_loss: 0.0779
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9921 - loss: 0.0265 - val_accuracy: 0.9780 - val_loss: 0.0803
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9936 - loss: 0.0221 - val_accuracy: 0.9748 - val_loss: 0.0942
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9950 - loss: 0.0173 - val_accuracy: 0.9772 - val_loss: 0.0835
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9960 - loss: 0.0148 - val_accuracy: 0.9767 - val_loss: 0.0864
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9964 - loss: 0.0125 - val_accuracy: 0.9777 - val_loss: 0.0873
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9950 - loss: 0.0155 - val_accuracy: 0.9759 - val_loss: 0.0957
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9973 - loss: 0.0105 - val_accuracy: 0.9777 - val_loss: 0.0938
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9978 - loss: 0.0082 - val_accuracy: 0.9786 - val_loss: 0.0986
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9978 - loss: 0.0080 - val_accuracy: 0.9738 - val_loss: 0.1210
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9977 - loss: 0.0079 - val_accuracy: 0.9755 - val_loss: 0.1108
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9976 - loss: 0.0077 - val_accuracy: 0.9785 - val_loss: 0.1015
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9976 - loss: 0.0074 - val_accuracy: 0.9776 - val_loss: 0.1112

# %%
# Cell 5: Vẽ training loss và validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss vs Validation Loss')
plt.legend()
plt.show()

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

# Xây dựng mô hình cải tiến
model_improved = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    Dropout(0.3),
    Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    Dropout(0.3),
    Dense(10, activation='softmax')
])

model_improved.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Thêm EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history_improved = model_improved.fit(
    x_train, y_train,
    epochs=20,
    batch_size=128,
    validation_data=(x_val, y_val),
    callbacks=[early_stop]
)

# Vẽ lại loss
plt.plot(history_improved.history['loss'], label='Train Loss')
plt.plot(history_improved.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Improved Model: Training vs Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.8249 - loss: 0.7792 - val_accuracy: 0.9417 - val_loss: 0.3804
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9209 - loss: 0.4420 - val_accuracy: 0.9576 - val_loss: 0.3068
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9341 - loss: 0.3751 - val_accuracy: 0.9646 - val_loss: 0.2662
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9430 - loss: 0.3287 - val_accuracy: 0.9691 - val_loss: 0.2363
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9474 - loss: 0.2998 - val_accuracy: 0.9701 - val_loss: 0.2216
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9522 - loss: 0.2835 - val_accuracy: 0.9705 - val_loss: 0.2111
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9536 - loss: 0.2693 - val_accuracy: 0.9727 - val_loss: 0.2032
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9545 - loss: 0.2609 - val_accuracy: 0.9737 - val_loss: 0.1955
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9571 - loss: 0.2518 - val_accuracy: 0.9721 - val_loss: 0.1991
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9578 - loss: 0.2487 - val_accuracy: 0.9738 - val_loss: 0.1928
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9591 - loss: 0.2427 - val_accuracy: 0.9753 - val_loss: 0.1867
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9599 - loss: 0.2378 - val_accuracy: 0.9724 - val_loss: 0.1913
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9611 - loss: 0.2314 - val_accuracy: 0.9760 - val_loss: 0.1789
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9598 - loss: 0.2317 - val_accuracy: 0.9745 - val_loss: 0.1783
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9621 - loss: 0.2237 - val_accuracy: 0.9758 - val_loss: 0.1794
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9604 - loss: 0.2254 - val_accuracy: 0.9753 - val_loss: 0.1793
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9623 - loss: 0.2242 - val_accuracy: 0.9743 - val_loss: 0.1805
