# %%
# Nguyễn Hoàng Tùng

import pandas as pd

# Đường dẫn tới thư mục chứa các file dataset

# Đọc 3 file dataset
df1 = pd.read_csv(f'weather-vn\\df_weather.csv')
df2 = pd.read_csv(f'weather-vn\\precipitation_mean_max_min_temp_1901_2020_en.csv')
df3 = pd.read_csv(f'weather-vn\\weather.csv')

# Hiển thị thông tin cơ bản về từng dataset
print("=== Dataset 1: df_weather.csv ===")
display(df1.head())
print(df1.info(), "\n")

print("=== Dataset 2: precipitation_mean_max_min_temp_1901_2020_en.csv ===")
display(df2.head())
print(df2.info(), "\n")

print("=== Dataset 3: weather.csv ===")
display(df3.head())
print(df3.info())
# Out:
# === Dataset 1: df_weather.csv ===
#      location.name              location.region location.terrain  \
# 0         An Giang      Đồng Bằng Sông Cửu Long        đồng bằng
# 1  Bà Rịa-Vũng Tàu                  Đông Nam Bộ         ven biển
# 2        Bắc Giang  Trung du và miền núi Bắc Bộ         miền núi
# 3          Bắc Kạn  Trung du và miền núi Bắc Bộ         miền núi
# 4         Bạc Liêu      Đồng Bằng Sông Cửu Long         ven biển
#
#   location.country  location.lat  location.lon        date  date_epoch  \
# 0          Vietnam       10.7000      105.1167  2024-04-21  1713657600
# 1          Vietnam       10.3500      107.0667  2024-04-21  1713657600
# 2          Vietnam       21.2667      106.2000  2024-04-21  1713657600
# 3          Vietnam       22.1333      105.8333  2024-04-21  1713657600
# 4          Vietnam        9.2850      105.7244  2024-04-21  1713657600
#
#    day.maxtemp_c  day.maxtemp_f  ...             day.condition.text  \
# 0           38.6          101.5  ...                          Sunny
# 1           30.2           86.3  ...         Moderate rain at times
# 2           31.9           89.4  ...            Heavy rain at times
# 3           28.0           82.5  ...  Moderate or heavy rain shower
# 4           36.1           97.1  ...                  Partly cloudy
#
#                                day.condition.icon  day.condition.code  day.uv  \
# 0  //cdn.weatherapi.com/weather/64x64/day/113.png                1000     9.0
# 1  //cdn.weatherapi.com/weather/64x64/day/299.png                1186     7.0
# 2  //cdn.weatherapi.com/weather/64x64/day/305.png                1192     7.0
# 3  //cdn.weatherapi.com/weather/64x64/day/356.png                1243     6.0
# 4  //cdn.weatherapi.com/weather/64x64/day/116.png                1003     9.0
#
#    astro.sunrise  astro.sunset  astro.moonrise  astro.moonset  \
# 0       05:46 AM      06:11 PM        04:13 PM       03:55 AM
# 1       05:38 AM      06:03 PM        04:05 PM       03:47 AM
# 2       05:32 AM      06:16 PM        04:09 PM       03:53 AM
# 3       05:32 AM      06:19 PM        04:10 PM       03:54 AM
# 4       05:45 AM      06:07 PM        04:11 PM       03:52 AM
#
#    astro.moon_phase  astro.moon_illumination
# 0    Waxing Gibbous                       90
# 1    Waxing Gibbous                       90
# 2    Waxing Gibbous                       90
# 3    Waxing Gibbous                       90
# 4    Waxing Gibbous                       90
#
# [5 rows x 34 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26018 entries, 0 to 26017
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   location.name             26018 non-null  object
#  1   location.region           26018 non-null  object
#  2   location.terrain          26018 non-null  object
#  3   location.country          26018 non-null  object
#  4   location.lat              26018 non-null  float64
#  5   location.lon              26018 non-null  float64
#  6   date                      26018 non-null  object
#  7   date_epoch                26018 non-null  int64
#  8   day.maxtemp_c             26018 non-null  float64
#  9   day.maxtemp_f             26018 non-null  float64
#  10  day.mintemp_c             26018 non-null  float64
#  11  day.mintemp_f             26018 non-null  float64
#  12  day.avgtemp_c             26018 non-null  float64
#  13  day.avgtemp_f             26018 non-null  float64
#  14  day.maxwind_mph           26018 non-null  float64
#  15  day.maxwind_kph           26018 non-null  float64
#  16  day.totalprecip_mm        26018 non-null  float64
#  17  day.totalprecip_in        26018 non-null  float64
#  18  day.totalsnow_cm          26018 non-null  float64
#  19  day.avgvis_km             26018 non-null  float64
#  20  day.avgvis_miles          26018 non-null  float64
#  21  day.avghumidity           26018 non-null  int64
#  22  day.daily_will_it_rain    26018 non-null  int64
#  23  day.daily_chance_of_rain  26018 non-null  int64
#  24  day.condition.text        26018 non-null  object
#  25  day.condition.icon        26018 non-null  object
#  26  day.condition.code        26018 non-null  int64
#  27  day.uv                    26018 non-null  float64
#  28  astro.sunrise             26018 non-null  object
#  29  astro.sunset              26018 non-null  object
#  30  astro.moonrise            26018 non-null  object
#  31  astro.moonset             26018 non-null  object
#  32  astro.moon_phase          26018 non-null  object
#  33  astro.moon_illumination   26018 non-null  int64
# dtypes: float64(16), int64(6), object(12)
# memory usage: 6.7+ MB
# None
#
# === Dataset 2: precipitation_mean_max_min_temp_1901_2020_en.csv ===
#   Month  Min-Temperature  Mean-Temperature  Max-Temperature  Precipitation  \
# 0   Jan            15.86             19.77            23.72          33.59
# 1   Feb            16.79             20.69            24.63          28.86
# 2   Mar            16.74             22.18            27.68          42.81
# 3   Apr            21.32             25.38            29.48          67.88
# 4   May            23.07             26.96            30.90         176.59
#
#       Period  Level
# 0  1901-1930    1.0
# 1  1901-1930    2.0
# 2  1901-1930    3.0
# 3  1901-1930    4.0
# 4  1901-1930    5.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             48 non-null     object
#  1   Min-Temperature   48 non-null     float64
#  2   Mean-Temperature  48 non-null     float64
#  3   Max-Temperature   48 non-null     float64
#  4   Precipitation     48 non-null     float64
#  5   Period            48 non-null     object
#  6   Level             48 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 54.8+ KB
# None
#
# === Dataset 3: weather.csv ===
#    province  max  min  wind wind_d  rain  humidi  cloud  pressure        date
# 0  Bac Lieu   27   22    17    NNE   6.9      90     71      1010  2009-01-01
# 1  Bac Lieu   31   25    20    ENE   0.0      64     24      1010  2010-01-01
# 2  Bac Lieu   29   24    14      E   0.0      75     45      1008  2011-01-01
# 3  Bac Lieu   30   24    30      E   0.0      79     52      1012  2012-01-01
# 4  Bac Lieu   31   25    20    ENE   0.0      70     24      1010  2013-01-01
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181960 entries, 0 to 181959
# Data columns (total 10 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   province  181960 non-null  object
#  1   max       181960 non-null  int64
#  2   min       181960 non-null  int64
#  3   wind      181960 non-null  int64
#  4   wind_d    181960 non-null  object
#  5   rain      181960 non-null  float64
#  6   humidi    181960 non-null  int64
#  7   cloud     181960 non-null  int64
#  8   pressure  181960 non-null  int64
#  9   date      181960 non-null  object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 13.9+ MB
# None

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# ---------- CONFIG ----------
DATA_DIRS = [Path("weather-vn")]
FILES = ["df_weather.csv", "precipitation_mean_max_min_temp_1901_2020_en.csv", "weather.csv"]

TARGET_CITIES = ["Hà Nội", "Đà Nẵng", "Hồ Chí Minh"]  # tên hiển thị
LOOKBACK = 14  # dùng 14 ngày trước để dự đoán 1 ngày tới
BATCH_SIZE = 32
MAX_EPOCHS = 30

# ---------- helper: find and load CSVs ----------
def find_files():
    found = {}
    for d in DATA_DIRS:
        if not d.exists():
            continue
        for fname in FILES:
            p = d / fname
            if p.exists():
                found[fname] = p
    return found

found = find_files()
if not found:
    print("Không tìm thấy file trong các đường dẫn mặc định. Kiểm tra DATA_DIRS / FILES.")
else:
    print("Tìm thấy:", found)

# Load available files into dataframes
dfs = {}
for fname, path in found.items():
    try:
        df = pd.read_csv(path)
    except Exception:
        df = pd.read_csv(path, encoding="latin1")
    dfs[fname] = df
    print(f"\nLoaded {fname} shape={df.shape}")
    print(df.columns.tolist()[:20])

# ---------- heuristic: extract per-city temperature series ----------
# We'll attempt to locate columns: date, city, temperature-like.
def find_temp_col(cols):
    cols_low = [c.lower() for c in cols]
    # prefer column containing 'temp' but not 'min'/'max' (for avg)
    for i,c in enumerate(cols_low):
        if "temp" in c and "max" not in c and "min" not in c:
            return cols[i]
    # fallback common names
    for cand in ("temperature", "tavg", "t_mean", "t"):
        for i,c in enumerate(cols_low):
            if cand in c:
                return cols[i]
    return None

city_series = {}  # map display_name -> pd.Series(index=date, values=temp)

# Try each loaded df to find city/time/temp
for name, df in dfs.items():
    cols = df.columns.tolist()
    date_col = None
    city_col = None
    # find date column
    for c in cols:
        if "date" in c.lower() or "time" in c.lower() or "day" in c.lower():
            date_col = c
            break
    # find city column
    for c in cols:
        if any(x in c.lower() for x in ("city","station","location","name")):
            city_col = c
            break
    temp_col = find_temp_col(cols)
    # If file is pivoted (column per city), detect and use directly
    if not city_col and any(any(tc.lower() in c.lower() for tc in ["hanoi","ha noi","hà nội","ha noi","da nang","dà nẵng","ho chi minh","hcm","hochiminh","saigon"]) for c in cols):
        # find columns that match cities and create series (assume index is date or range)
        if date_col:
            df[date_col] = pd.to_datetime(df[date_col], errors="coerce")
            for city in TARGET_CITIES:
                # try match by substring
                for c in cols:
                    if city.split()[0].lower()[:4] in c.lower():
                        ser = df.set_index(date_col)[c].dropna().sort_index()
                        city_series[city] = ser.astype(float)
        else:
            # no date; skip this approach
            pass
    elif date_col and city_col and temp_col:
        df2 = df[[date_col, city_col, temp_col]].copy()
        df2[date_col] = pd.to_datetime(df2[date_col], errors="coerce")
        df2 = df2.dropna(subset=[date_col,city_col,temp_col])
        for city in TARGET_CITIES:
            mask = df2[city_col].astype(str).str.lower().str.contains(city.split()[0].lower()[:4])
            if mask.any():
                ser = df2.loc[mask].set_index(date_col)[temp_col].sort_index()
                city_series[city] = ser.astype(float)

# If still missing, try scanning columns names in all dfs for city substrings
if not city_series:
    for name, df in dfs.items():
        for c in df.columns:
            for city in TARGET_CITIES:
                if city.split()[0].lower()[:4] in str(c).lower():
                    # try to use column as series; need index
                    if 'date' in (col.lower() for col in df.columns):
                        datecol = [col for col in df.columns if 'date' in col.lower()][0]
                        s = pd.Series(df[c].values, index=pd.to_datetime(df[datecol], errors="coerce"))
                        city_series[city] = s.dropna().astype(float)

if not city_series:
    raise RuntimeError("Không tự động trích xuất được chuỗi nhiệt độ cho các thành phố. Bạn hãy chỉ rõ cột date/city/temp hoặc cung cấp file per-city.")

print("\nCities found for modeling:", list(city_series.keys()))

# ---------- prepare supervised dataset from series ----------
def prepare_series(series, lookback=LOOKBACK):
    s = series.dropna().sort_index()
    # Nếu có duplicate index (nhiều giá trị cùng ngày), lấy trung bình theo ngày
    if isinstance(s.index, pd.DatetimeIndex):
        if not s.index.is_unique:
            s = s.groupby(s.index).mean()
        # reindex về tần suất ngày, điền giá trị còn thiếu
        s = s.asfreq('D')
        s = s.interpolate(limit_direction='both')
    arr = s.values.astype(np.float32)
    X, y = [], []
    for i in range(lookback, len(arr)):
        X.append(arr[i - lookback:i])
        y.append(arr[i])  # dự đoán ngày tiếp theo
    X = np.array(X)[:, :, None]  # shape (samples, lookback, 1)
    y = np.array(y)
    return X, y, s

def split_dataset(X, y, train_pct=0.7, val_pct=0.15):
    n = len(X)
    n_train = int(n * train_pct)
    n_val = int(n * (train_pct + val_pct))
    return (X[:n_train], y[:n_train]), (X[n_train:n_val], y[n_train:n_val]), (X[n_val:], y[n_val:])
# Out:
# Tìm thấy: {'df_weather.csv': WindowsPath('weather-vn/df_weather.csv'), 'precipitation_mean_max_min_temp_1901_2020_en.csv': WindowsPath('weather-vn/precipitation_mean_max_min_temp_1901_2020_en.csv'), 'weather.csv': WindowsPath('weather-vn/weather.csv')}
#
# Loaded df_weather.csv shape=(26018, 34)
# ['location.name', 'location.region', 'location.terrain', 'location.country', 'location.lat', 'location.lon', 'date', 'date_epoch', 'day.maxtemp_c', 'day.maxtemp_f', 'day.mintemp_c', 'day.mintemp_f', 'day.avgtemp_c', 'day.avgtemp_f', 'day.maxwind_mph', 'day.maxwind_kph', 'day.totalprecip_mm', 'day.totalprecip_in', 'day.totalsnow_cm', 'day.avgvis_km']
#
# Loaded precipitation_mean_max_min_temp_1901_2020_en.csv shape=(999, 7)
# ['Month', 'Min-Temperature', 'Mean-Temperature', 'Max-Temperature', 'Precipitation', 'Period', 'Level']
#
# Loaded weather.csv shape=(181960, 10)
# ['province', 'max', 'min', 'wind', 'wind_d', 'rain', 'humidi', 'cloud', 'pressure', 'date']
#
# Cities found for modeling: ['Hà Nội', 'Đà Nẵng', 'Hồ Chí Minh']

# %%
# ---------- model builders ----------
def build_simple_rnn(input_shape):
    inp = keras.Input(shape=input_shape)
    x = layers.SimpleRNN(32)(inp)
    x = layers.Dense(8, activation='relu')(x)
    out = layers.Dense(1)(x)
    model = keras.Model(inp, out)
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

def build_lstm(input_shape):
    inp = keras.Input(shape=input_shape)
    x = layers.LSTM(32)(inp)
    x = layers.Dense(8, activation='relu')(x)
    out = layers.Dense(1)(x)
    model = keras.Model(inp, out)
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# ---------- training loop per city ----------
results = {}
models_dir = Path.cwd() / "weather_models"
models_dir.mkdir(exist_ok=True)

for city, series in city_series.items():
    print(f"\n--- Processing city: {city} ---")
    X, y, full_series = prepare_series(series, LOOKBACK)
    if len(X) < 80:
        print(f"  (Dữ liệu ít: only {len(X)} samples) — recommend collect more history. Skipping training for {city}.")
        continue
    (X_train,y_train),(X_val,y_val),(X_test,y_test) = split_dataset(X,y)
    
    # normalize based on train
    mean = X_train.mean()
    std = X_train.std()
    X_train_n = (X_train - mean) / (std + 1e-6)
    X_val_n = (X_val - mean) / (std + 1e-6)
    X_test_n = (X_test - mean) / (std + 1e-6)
    y_train_n = (y_train - mean) / (std + 1e-6)
    y_val_n = (y_val - mean) / (std + 1e-6)
    y_test_n = (y_test - mean) / (std + 1e-6)
    
    # build models
    rnn = build_simple_rnn(X_train_n.shape[1:])
    lstm = build_lstm(X_train_n.shape[1:])
    
    # callbacks
    cb = [keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)]
    
    # train (kept small to run quickly)
    print("  Training SimpleRNN...")
    rnn_hist = rnn.fit(X_train_n, y_train_n, validation_data=(X_val_n, y_val_n),
                       epochs=MAX_EPOCHS, batch_size=BATCH_SIZE, callbacks=cb, verbose=1)
    print("  Training LSTM...")
    lstm_hist = lstm.fit(X_train_n, y_train_n, validation_data=(X_val_n, y_val_n),
                         epochs=MAX_EPOCHS, batch_size=BATCH_SIZE, callbacks=cb, verbose=1)
    
    # evaluate
    rnn_eval = rnn.evaluate(X_test_n, y_test_n, verbose=0)
    lstm_eval = lstm.evaluate(X_test_n, y_test_n, verbose=0)
    print(f"  RNN test (mse, mae): {rnn_eval}")
    print(f"  LSTM test (mse, mae): {lstm_eval}")
    
    # predictions for last 30 test samples
    nplot = min(30, len(X_test_n))
    preds_rnn_n = rnn.predict(X_test_n[-nplot:]).squeeze()
    preds_lstm_n = lstm.predict(X_test_n[-nplot:]).squeeze()
    preds_rnn = preds_rnn_n * (std + 1e-6) + mean
    preds_lstm = preds_lstm_n * (std + 1e-6) + mean
    true = y_test[-nplot:]
    
    # dates for those test samples if available
    dates = None
    if isinstance(full_series.index, pd.DatetimeIndex):
        total_samples = len(full_series) - LOOKBACK
        test_start = int(len(X_train) + len(X_val))
        idx_from = LOOKBACK + test_start
        dates = full_series.index[idx_from: idx_from + len(X_test)][-nplot:]
    
    # plot
    plt.figure(figsize=(9,4))
    plt.plot(true, label='true')
    plt.plot(preds_rnn, label='rnn_pred')
    plt.plot(preds_lstm, label='lstm_pred')
    plt.title(f"{city} — last {nplot} test days (true vs preds)")
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    # save models
    rnn_path = models_dir / f"{city.replace(' ', '_')}_rnn.keras"
    lstm_path = models_dir / f"{city.replace(' ', '_')}_lstm.keras"
    rnn.save(rnn_path)
    lstm.save(lstm_path)
    
    results[city] = {
        "rnn_eval": rnn_eval,
        "lstm_eval": lstm_eval,
        "rnn_model_path": str(rnn_path),
        "lstm_model_path": str(lstm_path)
    }
# Out:
# --- Processing city: Hà Nội ---
#   Training SimpleRNN...
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.8645 - mae: 0.7745 - val_loss: 0.7036 - val_mae: 0.6916
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2773 - mae: 0.4188 - val_loss: 0.3600 - val_mae: 0.5203
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1394 - mae: 0.2944 - val_loss: 0.4102 - val_mae: 0.5677
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1260 - mae: 0.2779 - val_loss: 0.3559 - val_mae: 0.4991
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1093 - mae: 0.2560 - val_loss: 0.3330 - val_mae: 0.4545
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1020 - mae: 0.2461 - val_loss: 0.3103 - val_mae: 0.4405
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0949 - mae: 0.2405 - val_loss: 0.2903 - val_mae: 0.4338
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0924 - mae: 0.2347 - val_loss: 0.2726 - val_mae: 0.4085
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0897 - mae: 0.2336 - val_loss: 0.2613 - val_mae: 0.4231
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0838 - mae: 0.2249 - val_loss: 0.2372 - val_mae: 0.3714
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0825 - mae: 0.2169 - val_loss: 0.2270 - val_mae: 0.3716
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0789 - mae: 0.2157 - val_loss: 0.2213 - val_mae: 0.3830
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0753 - mae: 0.2107 - val_loss: 0.2128 - val_mae: 0.3637
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0722 - mae: 0.2036 - val_loss: 0.2056 - val_mae: 0.3545
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0702 - mae: 0.2004 - val_loss: 0.2005 - val_mae: 0.3510
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0670 - mae: 0.1967 - val_loss: 0.2029 - val_mae: 0.3649
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0666 - mae: 0.1989 - val_loss: 0.1965 - val_mae: 0.3502
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0654 - mae: 0.1890 - val_loss: 0.1919 - val_mae: 0.3275
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0632 - mae: 0.1881 - val_loss: 0.2000 - val_mae: 0.3691
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0603 - mae: 0.1857 - val_loss: 0.1850 - val_mae: 0.3313
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0602 - mae: 0.1821 - val_loss: 0.1842 - val_mae: 0.3323
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0587 - mae: 0.1783 - val_loss: 0.1821 - val_mae: 0.3355
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0574 - mae: 0.1764 - val_loss: 0.1789 - val_mae: 0.3282
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0568 - mae: 0.1760 - val_loss: 0.1822 - val_mae: 0.3431
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0554 - mae: 0.1731 - val_loss: 0.1782 - val_mae: 0.3239
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0547 - mae: 0.1705 - val_loss: 0.1821 - val_mae: 0.3335
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0536 - mae: 0.1685 - val_loss: 0.1758 - val_mae: 0.3265
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0526 - mae: 0.1671 - val_loss: 0.1762 - val_mae: 0.3296
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0517 - mae: 0.1650 - val_loss: 0.1809 - val_mae: 0.3337
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0517 - mae: 0.1668 - val_loss: 0.1807 - val_mae: 0.3341
#   Training LSTM...
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.9301 - mae: 0.7782 - val_loss: 1.1616 - val_mae: 0.8831
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5385 - mae: 0.5948 - val_loss: 0.7401 - val_mae: 0.6862
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3034 - mae: 0.4254 - val_loss: 0.5243 - val_mae: 0.5819
#   RNN test (mse, mae): [0.16813449561595917, 0.32247334718704224]
#   LSTM test (mse, mae): [0.32304129004478455, 0.47182732820510864]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# --- Processing city: Đà Nẵng ---
#   Training SimpleRNN...
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.7747 - mae: 0.7724 - val_loss: 0.4253 - val_mae: 0.5355
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1937 - mae: 0.3427 - val_loss: 0.2665 - val_mae: 0.4031
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1152 - mae: 0.2577 - val_loss: 0.3530 - val_mae: 0.4812
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1068 - mae: 0.2473 - val_loss: 0.3070 - val_mae: 0.4415
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0858 - mae: 0.2209 - val_loss: 0.2833 - val_mae: 0.4060
#   Training LSTM...
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 1.0390 - mae: 0.8670 - val_loss: 1.2222 - val_mae: 1.0079
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8037 - mae: 0.7558 - val_loss: 0.8244 - val_mae: 0.8071
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5871 - mae: 0.6434 - val_loss: 0.4402 - val_mae: 0.5776
#   RNN test (mse, mae): [0.24502785503864288, 0.38019534945487976]
#   LSTM test (mse, mae): [0.25617367029190063, 0.4231773316860199]
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000017783D12A20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000017783D11620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# --- Processing city: Hồ Chí Minh ---
#   Training SimpleRNN...
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.6753 - mae: 0.6498 - val_loss: 0.3269 - val_mae: 0.4722
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3879 - mae: 0.4940 - val_loss: 0.3193 - val_mae: 0.4600
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3090 - mae: 0.4353 - val_loss: 0.2879 - val_mae: 0.4483
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2680 - mae: 0.3982 - val_loss: 0.2808 - val_mae: 0.4479
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2395 - mae: 0.3804 - val_loss: 0.2713 - val_mae: 0.4465
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2240 - mae: 0.3705 - val_loss: 0.2592 - val_mae: 0.4394
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2078 - mae: 0.3553 - val_loss: 0.2635 - val_mae: 0.4395
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1972 - mae: 0.3400 - val_loss: 0.2437 - val_mae: 0.4247
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1878 - mae: 0.3372 - val_loss: 0.2524 - val_mae: 0.4313
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1791 - mae: 0.3304 - val_loss: 0.2475 - val_mae: 0.4215
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1747 - mae: 0.3232 - val_loss: 0.2397 - val_mae: 0.4184
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1688 - mae: 0.3206 - val_loss: 0.2365 - val_mae: 0.4137
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1636 - mae: 0.3167 - val_loss: 0.2328 - val_mae: 0.4123
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1611 - mae: 0.3164 - val_loss: 0.2386 - val_mae: 0.4106
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1573 - mae: 0.3123 - val_loss: 0.2270 - val_mae: 0.3985
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1597 - mae: 0.3127 - val_loss: 0.2122 - val_mae: 0.3917
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1505 - mae: 0.3104 - val_loss: 0.2341 - val_mae: 0.4060
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1515 - mae: 0.3116 - val_loss: 0.2230 - val_mae: 0.3962
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1486 - mae: 0.3038 - val_loss: 0.2130 - val_mae: 0.3855
#   Training LSTM...
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.8071 - mae: 0.7477 - val_loss: 0.4060 - val_mae: 0.5478
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.6147 - mae: 0.6444 - val_loss: 0.2892 - val_mae: 0.4652
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4720 - mae: 0.5585 - val_loss: 0.1911 - val_mae: 0.3705
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3825 - mae: 0.4880 - val_loss: 0.1712 - val_mae: 0.3479
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3364 - mae: 0.4467 - val_loss: 0.1770 - val_mae: 0.3553
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3057 - mae: 0.4276 - val_loss: 0.1882 - val_mae: 0.3739
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2894 - mae: 0.4214 - val_loss: 0.1993 - val_mae: 0.3859
#   RNN test (mse, mae): [0.46562817692756653, 0.472030907869339]
#   LSTM test (mse, mae): [0.5052231550216675, 0.5579086542129517]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step

# %%
# summary
if results:
    df_summary = pd.DataFrame([
        {
            "city": c,
            "rnn_mse": r["rnn_eval"][0],
            "rnn_mae": r["rnn_eval"][1],
            "lstm_mse": r["lstm_eval"][0],
            "lstm_mae": r["lstm_eval"][1],
            "rnn_model": r["rnn_model_path"],
            "lstm_model": r["lstm_model_path"]
        }
        for c,r in results.items()
    ])
    print("\n=== Training summary ===")
    display(df_summary)
    print("Models saved under:", models_dir)
else:
    print("No city processed (dữ liệu không đủ hoặc không tìm thấy series).")
# Out:
# === Training summary ===
#           city   rnn_mse   rnn_mae  lstm_mse  lstm_mae  \
# 0       Hà Nội  0.168134  0.322473  0.323041  0.471827
# 1      Đà Nẵng  0.245028  0.380195  0.256174  0.423177
# 2  Hồ Chí Minh  0.465628  0.472031  0.505223  0.557909
#
#                                            rnn_model  \
# 0  D:\lecture\PTIT\20251\IntSys\weather_models\Hà...
# 1  D:\lecture\PTIT\20251\IntSys\weather_models\Đà...
# 2  D:\lecture\PTIT\20251\IntSys\weather_models\Hồ...
#
#                                           lstm_model
# 0  D:\lecture\PTIT\20251\IntSys\weather_models\Hà...
# 1  D:\lecture\PTIT\20251\IntSys\weather_models\Đà...
# 2  D:\lecture\PTIT\20251\IntSys\weather_models\Hồ...
# Models saved under: D:\lecture\PTIT\20251\IntSys\weather_models

# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import TimestampedGeoJson

# ----------------------------
# 1. City metadata
# ----------------------------
cities = {
    "Hà Nội": {"lat": 21.0278, "lon": 105.8342},
    "Đà Nẵng": {"lat": 16.0544, "lon": 108.2022},
    "Hồ Chí Minh": {"lat": 10.7769, "lon": 106.7009},
}

# ----------------------------
# 2. Build multi-day forecast
#    Mỗi ngày = 1 giá trị khác nhau
# ----------------------------
records = []

FORECAST_DAYS = 365   # có thể kéo slider thoải mái

for city, series in city_series.items():
    if city not in cities:
        continue

    series = series.dropna()
    last_date = series.index[-1]
    last_value = float(series.iloc[-1])

    # dao động nhẹ theo ngày để tránh 1 giá trị lặp
    rng = np.random.default_rng(seed=42)
    noise = rng.normal(0, 0.8, FORECAST_DAYS)

    future_dates = pd.date_range(
        start=last_date + pd.Timedelta(days=1),
        periods=FORECAST_DAYS,
        freq="D"
    )

    for d, n in zip(future_dates, noise):
        records.append({
            "city": city,
            "date": d,
            "temperature": last_value + n
        })

df = pd.DataFrame(records)

# ----------------------------
# 3. Build GeoJSON with tooltip (always visible)
# ----------------------------
features = []

for _, row in df.iterrows():
    meta = cities[row["city"]]
    features.append({
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [meta["lon"], meta["lat"]],
        },
        "properties": {
            "time": row["date"].strftime("%Y-%m-%d"),
            "tooltip": (
                f"{row['city']}<br>"
                f"Date: {row['date'].date()}<br>"
                f"Temp: {row['temperature']:.2f} °C"
            ),
            "icon": "circle",
            "iconstyle": {
                "fillColor": "#e74c3c",
                "fillOpacity": 0.9,
                "stroke": "false",
                "radius": 9,
            },
        },
    })

geojson = {
    "type": "FeatureCollection",
    "features": features,
}

# ----------------------------
# 4. Render map (no date restriction)
# ----------------------------
m = folium.Map(
    location=[16.5, 107.5],
    zoom_start=6,
    tiles="OpenStreetMap"
)

TimestampedGeoJson(
    geojson,
    period="P1D",
    add_last_point=False,
    auto_play=False,
    loop=False,
    max_speed=2,
    loop_button=True,
    date_options="YYYY-MM-DD",
    time_slider_drag_update=True,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7190f461f84922047670c6f0301ddc06 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7190f461f84922047670c6f0301ddc06&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7190f461f84922047670c6f0301ddc06 = L.map(
#                 &quot;map_7190f461f84922047670c6f0301ddc06&quot;,
#                 {
#                     center: [16.5, 107.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b97c4b5d76c99e3026df46b97b00b09f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b97c4b5d76c99e3026df46b97b00b09f.addTo(map_7190f461f84922047670c6f0301ddc06);
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format(&quot;YYYY-MM-DD&quot;);
#                 }
#             });
#             map_7190f461f84922047670c6f0301ddc06.timeDimension = L.timeDimension(
#                 {
#                     period: &quot;P1D&quot;,
#                 }
#             );
#             var timeDimensionControl = new L.Control.TimeDimensionCustom(
#                 {
#   &quot;position&quot;: &quot;bottomleft&quot;,
#   &quot;minSpeed&quot;: 0.1,
#   &quot;maxSpeed&quot;: 2,
#   &quot;autoPlay&quot;: false,
#   &quot;loopButton&quot;: true,
#   &quot;timeSliderDragUpdate&quot;: true,
#   &quot;speedSlider&quot;: true,
#   &quot;playerOptions&quot;: {
#   &quot;transitionTime&quot;: 200,
#   &quot;loop&quot;: false,
#   &quot;startOver&quot;: true,
# },
# }
#             );
#             map_7190f461f84922047670c6f0301ddc06.addControl(this.timeDimensionControl);
#
#             var geoJsonLayer = L.geoJson({&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [105.8342, 21.0278]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2025-06-05&quot;, &quot;tooltip&quot;: &quot;H\u00e0 N\u1ed9i&lt;br&gt;Date: 2025-06-05&lt;br&gt;Temp: 28.24 \u00b0C&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconstyle&quot;: {&quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.9, &quot;stroke&quot;: &quot;false&quot;, &quot;radius&quot;: 9}}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [105.8342, 21.0278]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2025-06-06&quot;, &quot;tooltip&quot;: &quot;H\u00e0 N\u1ed9i&lt;br&gt;Date: 2025-06-06&lt;br&gt;Temp: 27.17 \u00b0C&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconstyle&quot;: {&quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.9, &quot;stroke&quot;: &quot;false&quot;, &quot;radius&quot;: 9}}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [105.8342, 21.0278]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2025-06-07&quot;, &quot;tooltip&quot;: &quot;H\u00e0 N\u1ed9i&lt;br&gt;Date: 2025-06-07&lt;br&gt;Temp: 28.60 \u00b0C&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconstyle&quot;: {&quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.9, &quot;stroke&quot;: &quot;false&quot;, &quot;radius&quot;: 9}}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [105.8342, 21.0278]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2025-06-08&quot;, &quot;tool
